# %%
import warnings
#warnings.filterwarnings('ignore')

import numpy as np
import pandas as pd

import mne
from mne import Epochs, pick_types, find_events
from mne.channels import read_layout
from mne.io import concatenate_raws, read_raw_gdf
from mne.decoding import CSP
from sklearn.preprocessing import LabelEncoder

import tensorflow as tf
import tensorflow.keras as keras
from tensorflow.keras.callbacks import Callback
from tensorflow.keras import utils as np_utils
from tensorflow.keras.callbacks import ModelCheckpoint
from EEGModels import EEGNet


'''
Parameters:
'''
tmin = 0
tmax = 10

# %%
object_names = ['P01', 'P02', 'P03', 'P04', 'P05', 'P06']
# object_names = ['P01', 'P02', 'P03', 'P04']
files = []
for name in object_names:
    for i in range(15):
        files.append(read_raw_gdf(f'..\\{name}\\{name} Run {i+1}.gdf', stim_channel=None, eog=[61,62,63]))
# Out:
# Extracting EDF parameters from D:\EEGTest\Attempted arm and hand movements in persons with spinal cord injury\P01\P01 Run 1.gdf...
# GDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\EEGTest\Attempted arm and hand movements in persons with spinal cord injury\P01\P01 Run 2.gdf...
# GDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\EEGTest\Attempted arm and hand movements in persons with spinal cord injury\P01\P01 Run 3.gdf...
# GDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\EEGTest\Attempted arm and hand movements in persons with spinal cord injury\P01\P01 Run 4.gdf...
# GDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\EEGTest\Attempted arm and hand movements in persons with spinal cord injury\P01\P01 Run 5.gdf...
# GDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\EEGTest\Attempted arm and hand movements in persons with spinal cord injury\P01\P01 Run 6.gdf...
# GDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\EEGTest\Attempted arm and hand movements in persons with spinal cord injury\P01\P01 Run 7.gdf...
# GDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\EEGTest\Attempted arm and hand movements in persons with spinal cord injury\P01\P01 Run 8.gdf...
# GDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\EEGTest\Attempted arm and hand movements in persons with spinal cord injury\P01\P01 Run 9.gdf...
# GDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\EEGTest\Attempted arm and hand movements in persons with spinal cord injury\P01\P01 Run 10.gdf...
# GDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\EEGTest\Attempted arm and hand movements in persons with spinal cord injury\P01\P01 Run 11.gdf...
# GDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\EEGTest\Attempted arm and hand movements in persons with spinal cord injury\P01\P01 Run 12.gdf...
# GDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\EEGTest\Attempted arm and hand movements in persons with spinal cord injury\P01\P01 Run 13.gdf...
# GDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\EEGTest\Attempted arm and hand movements in persons with spinal cord injury\P01\P01 Run 14.gdf...
# GDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\EEGTest\Attempted arm and hand movements in persons with spinal cord injury\P01\P01 Run 15.gdf...
# GDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\EEGTest\Attempted arm and hand movements in persons with spinal cord injury\P02\P02 Run 1.gdf...
# GDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\EEGTest\Attempted arm and hand movements in persons with spinal cord injury\P02\P02 Run 2.gdf...
# GDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\EEGTest\Attempted arm and hand movements in persons with spinal cord injury\P02\P02 Run 3.gdf...
# GDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\EEGTest\Attempted arm and hand movements in persons with spinal cord injury\P02\P02 Run 4.gdf...
# GDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\EEGTest\Attempted arm and hand movements in persons with spinal cord injury\P02\P02 Run 5.gdf...
# GDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\EEGTest\Attempted arm and hand movements in persons with spinal cord injury\P02\P02 Run 6.gdf...
# GDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\EEGTest\Attempted arm and hand movements in persons with spinal cord injury\P02\P02 Run 7.gdf...
# GDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\EEGTest\Attempted arm and hand movements in persons with spinal cord injury\P02\P02 Run 8.gdf...
# GDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\EEGTest\Attempted arm and hand movements in persons with spinal cord injury\P02\P02 Run 9.gdf...
# GDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\EEGTest\Attempted arm and hand movements in persons with spinal cord injury\P02\P02 Run 10.gdf...
# GDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\EEGTest\Attempted arm and hand movements in persons with spinal cord injury\P02\P02 Run 11.gdf...
# GDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\EEGTest\Attempted arm and hand movements in persons with spinal cord injury\P02\P02 Run 12.gdf...
# GDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\EEGTest\Attempted arm and hand movements in persons with spinal cord injury\P02\P02 Run 13.gdf...
# GDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\EEGTest\Attempted arm and hand movements in persons with spinal cord injury\P02\P02 Run 14.gdf...
# GDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\EEGTest\Attempted arm and hand movements in persons with spinal cord injury\P02\P02 Run 15.gdf...
# GDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\EEGTest\Attempted arm and hand movements in persons with spinal cord injury\P03\P03 Run 1.gdf...
# GDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\EEGTest\Attempted arm and hand movements in persons with spinal cord injury\P03\P03 Run 2.gdf...
# GDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\EEGTest\Attempted arm and hand movements in persons with spinal cord injury\P03\P03 Run 3.gdf...
# GDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\EEGTest\Attempted arm and hand movements in persons with spinal cord injury\P03\P03 Run 4.gdf...
# GDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\EEGTest\Attempted arm and hand movements in persons with spinal cord injury\P03\P03 Run 5.gdf...
# GDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\EEGTest\Attempted arm and hand movements in persons with spinal cord injury\P03\P03 Run 6.gdf...
# GDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\EEGTest\Attempted arm and hand movements in persons with spinal cord injury\P03\P03 Run 7.gdf...
# GDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\EEGTest\Attempted arm and hand movements in persons with spinal cord injury\P03\P03 Run 8.gdf...
# GDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\EEGTest\Attempted arm and hand movements in persons with spinal cord injury\P03\P03 Run 9.gdf...
# GDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\EEGTest\Attempted arm and hand movements in persons with spinal cord injury\P03\P03 Run 10.gdf...
# GDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\EEGTest\Attempted arm and hand movements in persons with spinal cord injury\P03\P03 Run 11.gdf...
# GDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\EEGTest\Attempted arm and hand movements in persons with spinal cord injury\P03\P03 Run 12.gdf...
# GDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\EEGTest\Attempted arm and hand movements in persons with spinal cord injury\P03\P03 Run 13.gdf...
# GDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\EEGTest\Attempted arm and hand movements in persons with spinal cord injury\P03\P03 Run 14.gdf...
# GDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\EEGTest\Attempted arm and hand movements in persons with spinal cord injury\P03\P03 Run 15.gdf...
# GDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\EEGTest\Attempted arm and hand movements in persons with spinal cord injury\P04\P04 Run 1.gdf...
# GDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\EEGTest\Attempted arm and hand movements in persons with spinal cord injury\P04\P04 Run 2.gdf...
# GDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\EEGTest\Attempted arm and hand movements in persons with spinal cord injury\P04\P04 Run 3.gdf...
# GDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\EEGTest\Attempted arm and hand movements in persons with spinal cord injury\P04\P04 Run 4.gdf...
# GDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\EEGTest\Attempted arm and hand movements in persons with spinal cord injury\P04\P04 Run 5.gdf...
# GDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\EEGTest\Attempted arm and hand movements in persons with spinal cord injury\P04\P04 Run 6.gdf...
# GDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\EEGTest\Attempted arm and hand movements in persons with spinal cord injury\P04\P04 Run 7.gdf...
# GDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\EEGTest\Attempted arm and hand movements in persons with spinal cord injury\P04\P04 Run 8.gdf...
# GDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\EEGTest\Attempted arm and hand movements in persons with spinal cord injury\P04\P04 Run 9.gdf...
# GDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\EEGTest\Attempted arm and hand movements in persons with spinal cord injury\P04\P04 Run 10.gdf...
# GDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\EEGTest\Attempted arm and hand movements in persons with spinal cord injury\P04\P04 Run 11.gdf...
# GDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\EEGTest\Attempted arm and hand movements in persons with spinal cord injury\P04\P04 Run 12.gdf...
# GDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\EEGTest\Attempted arm and hand movements in persons with spinal cord injury\P04\P04 Run 13.gdf...
# GDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\EEGTest\Attempted arm and hand movements in persons with spinal cord injury\P04\P04 Run 14.gdf...
# GDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\EEGTest\Attempted arm and hand movements in persons with spinal cord injury\P04\P04 Run 15.gdf...
# GDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\EEGTest\Attempted arm and hand movements in persons with spinal cord injury\P05\P05 Run 1.gdf...
# GDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\EEGTest\Attempted arm and hand movements in persons with spinal cord injury\P05\P05 Run 2.gdf...
# GDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\EEGTest\Attempted arm and hand movements in persons with spinal cord injury\P05\P05 Run 3.gdf...
# GDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\EEGTest\Attempted arm and hand movements in persons with spinal cord injury\P05\P05 Run 4.gdf...
# GDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\EEGTest\Attempted arm and hand movements in persons with spinal cord injury\P05\P05 Run 5.gdf...
# GDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\EEGTest\Attempted arm and hand movements in persons with spinal cord injury\P05\P05 Run 6.gdf...
# GDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\EEGTest\Attempted arm and hand movements in persons with spinal cord injury\P05\P05 Run 7.gdf...
# GDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\EEGTest\Attempted arm and hand movements in persons with spinal cord injury\P05\P05 Run 8.gdf...
# GDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\EEGTest\Attempted arm and hand movements in persons with spinal cord injury\P05\P05 Run 9.gdf...
# GDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\EEGTest\Attempted arm and hand movements in persons with spinal cord injury\P05\P05 Run 10.gdf...
# GDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\EEGTest\Attempted arm and hand movements in persons with spinal cord injury\P05\P05 Run 11.gdf...
# GDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\EEGTest\Attempted arm and hand movements in persons with spinal cord injury\P05\P05 Run 12.gdf...
# GDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\EEGTest\Attempted arm and hand movements in persons with spinal cord injury\P05\P05 Run 13.gdf...
# GDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\EEGTest\Attempted arm and hand movements in persons with spinal cord injury\P05\P05 Run 14.gdf...
# GDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\EEGTest\Attempted arm and hand movements in persons with spinal cord injury\P05\P05 Run 15.gdf...
# GDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\EEGTest\Attempted arm and hand movements in persons with spinal cord injury\P06\P06 Run 1.gdf...
# GDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\EEGTest\Attempted arm and hand movements in persons with spinal cord injury\P06\P06 Run 2.gdf...
# GDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\EEGTest\Attempted arm and hand movements in persons with spinal cord injury\P06\P06 Run 3.gdf...
# GDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\EEGTest\Attempted arm and hand movements in persons with spinal cord injury\P06\P06 Run 4.gdf...
# GDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\EEGTest\Attempted arm and hand movements in persons with spinal cord injury\P06\P06 Run 5.gdf...
# GDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\EEGTest\Attempted arm and hand movements in persons with spinal cord injury\P06\P06 Run 6.gdf...
# GDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\EEGTest\Attempted arm and hand movements in persons with spinal cord injury\P06\P06 Run 7.gdf...
# GDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\EEGTest\Attempted arm and hand movements in persons with spinal cord injury\P06\P06 Run 8.gdf...
# GDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\EEGTest\Attempted arm and hand movements in persons with spinal cord injury\P06\P06 Run 9.gdf...
# GDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\EEGTest\Attempted arm and hand movements in persons with spinal cord injury\P06\P06 Run 10.gdf...
# GDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\EEGTest\Attempted arm and hand movements in persons with spinal cord injury\P06\P06 Run 11.gdf...
# GDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\EEGTest\Attempted arm and hand movements in persons with spinal cord injury\P06\P06 Run 12.gdf...
# GDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\EEGTest\Attempted arm and hand movements in persons with spinal cord injury\P06\P06 Run 13.gdf...
# GDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\EEGTest\Attempted arm and hand movements in persons with spinal cord injury\P06\P06 Run 14.gdf...
# GDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from D:\EEGTest\Attempted arm and hand movements in persons with spinal cord injury\P06\P06 Run 15.gdf...
# GDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# C:\Users\kings\Anaconda3\envs\mne\lib\site-packages\mne\io\edf\edf.py:996: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   etmode = np.fromstring(etmode, np.uint8).tolist()[0]
# C:\Users\kings\Anaconda3\envs\mne\lib\site-packages\mne\io\edf\edf.py:996: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   etmode = np.fromstring(etmode, np.uint8).tolist()[0]
# C:\Users\kings\Anaconda3\envs\mne\lib\site-packages\mne\io\edf\edf.py:996: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   etmode = np.fromstring(etmode, np.uint8).tolist()[0]
# C:\Users\kings\Anaconda3\envs\mne\lib\site-packages\mne\io\edf\edf.py:996: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   etmode = np.fromstring(etmode, np.uint8).tolist()[0]
# C:\Users\kings\Anaconda3\envs\mne\lib\site-packages\mne\io\edf\edf.py:996: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   etmode = np.fromstring(etmode, np.uint8).tolist()[0]
# C:\Users\kings\Anaconda3\envs\mne\lib\site-packages\mne\io\edf\edf.py:996: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   etmode = np.fromstring(etmode, np.uint8).tolist()[0]
# C:\Users\kings\Anaconda3\envs\mne\lib\site-packages\mne\io\edf\edf.py:996: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   etmode = np.fromstring(etmode, np.uint8).tolist()[0]
# C:\Users\kings\Anaconda3\envs\mne\lib\site-packages\mne\io\edf\edf.py:996: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   etmode = np.fromstring(etmode, np.uint8).tolist()[0]
# C:\Users\kings\Anaconda3\envs\mne\lib\site-packages\mne\io\edf\edf.py:996: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   etmode = np.fromstring(etmode, np.uint8).tolist()[0]
# C:\Users\kings\Anaconda3\envs\mne\lib\site-packages\mne\io\edf\edf.py:996: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   etmode = np.fromstring(etmode, np.uint8).tolist()[0]
# C:\Users\kings\Anaconda3\envs\mne\lib\site-packages\mne\io\edf\edf.py:996: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   etmode = np.fromstring(etmode, np.uint8).tolist()[0]
# C:\Users\kings\Anaconda3\envs\mne\lib\site-packages\mne\io\edf\edf.py:996: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   etmode = np.fromstring(etmode, np.uint8).tolist()[0]
# C:\Users\kings\Anaconda3\envs\mne\lib\site-packages\mne\io\edf\edf.py:996: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   etmode = np.fromstring(etmode, np.uint8).tolist()[0]
# C:\Users\kings\Anaconda3\envs\mne\lib\site-packages\mne\io\edf\edf.py:996: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   etmode = np.fromstring(etmode, np.uint8).tolist()[0]
# C:\Users\kings\Anaconda3\envs\mne\lib\site-packages\mne\io\edf\edf.py:996: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   etmode = np.fromstring(etmode, np.uint8).tolist()[0]
# C:\Users\kings\Anaconda3\envs\mne\lib\site-packages\mne\io\edf\edf.py:996: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   etmode = np.fromstring(etmode, np.uint8).tolist()[0]
# C:\Users\kings\Anaconda3\envs\mne\lib\site-packages\mne\io\edf\edf.py:996: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   etmode = np.fromstring(etmode, np.uint8).tolist()[0]
# C:\Users\kings\Anaconda3\envs\mne\lib\site-packages\mne\io\edf\edf.py:996: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   etmode = np.fromstring(etmode, np.uint8).tolist()[0]
# C:\Users\kings\Anaconda3\envs\mne\lib\site-packages\mne\io\edf\edf.py:996: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   etmode = np.fromstring(etmode, np.uint8).tolist()[0]
# C:\Users\kings\Anaconda3\envs\mne\lib\site-packages\mne\io\edf\edf.py:996: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   etmode = np.fromstring(etmode, np.uint8).tolist()[0]
# C:\Users\kings\Anaconda3\envs\mne\lib\site-packages\mne\io\edf\edf.py:996: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   etmode = np.fromstring(etmode, np.uint8).tolist()[0]
# C:\Users\kings\Anaconda3\envs\mne\lib\site-packages\mne\io\edf\edf.py:996: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   etmode = np.fromstring(etmode, np.uint8).tolist()[0]
# C:\Users\kings\Anaconda3\envs\mne\lib\site-packages\mne\io\edf\edf.py:996: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   etmode = np.fromstring(etmode, np.uint8).tolist()[0]
# C:\Users\kings\Anaconda3\envs\mne\lib\site-packages\mne\io\edf\edf.py:996: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   etmode = np.fromstring(etmode, np.uint8).tolist()[0]
# C:\Users\kings\Anaconda3\envs\mne\lib\site-packages\mne\io\edf\edf.py:996: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   etmode = np.fromstring(etmode, np.uint8).tolist()[0]
# C:\Users\kings\Anaconda3\envs\mne\lib\site-packages\mne\io\edf\edf.py:996: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   etmode = np.fromstring(etmode, np.uint8).tolist()[0]
# C:\Users\kings\Anaconda3\envs\mne\lib\site-packages\mne\io\edf\edf.py:996: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   etmode = np.fromstring(etmode, np.uint8).tolist()[0]
# C:\Users\kings\Anaconda3\envs\mne\lib\site-packages\mne\io\edf\edf.py:996: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   etmode = np.fromstring(etmode, np.uint8).tolist()[0]
# C:\Users\kings\Anaconda3\envs\mne\lib\site-packages\mne\io\edf\edf.py:996: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   etmode = np.fromstring(etmode, np.uint8).tolist()[0]
# C:\Users\kings\Anaconda3\envs\mne\lib\site-packages\mne\io\edf\edf.py:996: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   etmode = np.fromstring(etmode, np.uint8).tolist()[0]
# C:\Users\kings\Anaconda3\envs\mne\lib\site-packages\mne\io\edf\edf.py:996: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   etmode = np.fromstring(etmode, np.uint8).tolist()[0]
# C:\Users\kings\Anaconda3\envs\mne\lib\site-packages\mne\io\edf\edf.py:996: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   etmode = np.fromstring(etmode, np.uint8).tolist()[0]
# C:\Users\kings\Anaconda3\envs\mne\lib\site-packages\mne\io\edf\edf.py:996: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   etmode = np.fromstring(etmode, np.uint8).tolist()[0]
# C:\Users\kings\Anaconda3\envs\mne\lib\site-packages\mne\io\edf\edf.py:996: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   etmode = np.fromstring(etmode, np.uint8).tolist()[0]
# C:\Users\kings\Anaconda3\envs\mne\lib\site-packages\mne\io\edf\edf.py:996: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   etmode = np.fromstring(etmode, np.uint8).tolist()[0]
# C:\Users\kings\Anaconda3\envs\mne\lib\site-packages\mne\io\edf\edf.py:996: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   etmode = np.fromstring(etmode, np.uint8).tolist()[0]
# C:\Users\kings\Anaconda3\envs\mne\lib\site-packages\mne\io\edf\edf.py:996: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   etmode = np.fromstring(etmode, np.uint8).tolist()[0]
# C:\Users\kings\Anaconda3\envs\mne\lib\site-packages\mne\io\edf\edf.py:996: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   etmode = np.fromstring(etmode, np.uint8).tolist()[0]
# C:\Users\kings\Anaconda3\envs\mne\lib\site-packages\mne\io\edf\edf.py:996: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   etmode = np.fromstring(etmode, np.uint8).tolist()[0]
# C:\Users\kings\Anaconda3\envs\mne\lib\site-packages\mne\io\edf\edf.py:996: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   etmode = np.fromstring(etmode, np.uint8).tolist()[0]
# C:\Users\kings\Anaconda3\envs\mne\lib\site-packages\mne\io\edf\edf.py:996: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   etmode = np.fromstring(etmode, np.uint8).tolist()[0]
# C:\Users\kings\Anaconda3\envs\mne\lib\site-packages\mne\io\edf\edf.py:996: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   etmode = np.fromstring(etmode, np.uint8).tolist()[0]
# C:\Users\kings\Anaconda3\envs\mne\lib\site-packages\mne\io\edf\edf.py:996: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   etmode = np.fromstring(etmode, np.uint8).tolist()[0]
# C:\Users\kings\Anaconda3\envs\mne\lib\site-packages\mne\io\edf\edf.py:996: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   etmode = np.fromstring(etmode, np.uint8).tolist()[0]
# C:\Users\kings\Anaconda3\envs\mne\lib\site-packages\mne\io\edf\edf.py:996: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   etmode = np.fromstring(etmode, np.uint8).tolist()[0]
# C:\Users\kings\Anaconda3\envs\mne\lib\site-packages\mne\io\edf\edf.py:996: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   etmode = np.fromstring(etmode, np.uint8).tolist()[0]
# C:\Users\kings\Anaconda3\envs\mne\lib\site-packages\mne\io\edf\edf.py:996: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   etmode = np.fromstring(etmode, np.uint8).tolist()[0]
# C:\Users\kings\Anaconda3\envs\mne\lib\site-packages\mne\io\edf\edf.py:996: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   etmode = np.fromstring(etmode, np.uint8).tolist()[0]
# C:\Users\kings\Anaconda3\envs\mne\lib\site-packages\mne\io\edf\edf.py:996: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   etmode = np.fromstring(etmode, np.uint8).tolist()[0]
# C:\Users\kings\Anaconda3\envs\mne\lib\site-packages\mne\io\edf\edf.py:996: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   etmode = np.fromstring(etmode, np.uint8).tolist()[0]
# C:\Users\kings\Anaconda3\envs\mne\lib\site-packages\mne\io\edf\edf.py:996: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   etmode = np.fromstring(etmode, np.uint8).tolist()[0]
# C:\Users\kings\Anaconda3\envs\mne\lib\site-packages\mne\io\edf\edf.py:996: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   etmode = np.fromstring(etmode, np.uint8).tolist()[0]
# C:\Users\kings\Anaconda3\envs\mne\lib\site-packages\mne\io\edf\edf.py:996: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   etmode = np.fromstring(etmode, np.uint8).tolist()[0]
# C:\Users\kings\Anaconda3\envs\mne\lib\site-packages\mne\io\edf\edf.py:996: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   etmode = np.fromstring(etmode, np.uint8).tolist()[0]
# C:\Users\kings\Anaconda3\envs\mne\lib\site-packages\mne\io\edf\edf.py:996: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   etmode = np.fromstring(etmode, np.uint8).tolist()[0]
# C:\Users\kings\Anaconda3\envs\mne\lib\site-packages\mne\io\edf\edf.py:996: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   etmode = np.fromstring(etmode, np.uint8).tolist()[0]
# C:\Users\kings\Anaconda3\envs\mne\lib\site-packages\mne\io\edf\edf.py:996: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   etmode = np.fromstring(etmode, np.uint8).tolist()[0]
# C:\Users\kings\Anaconda3\envs\mne\lib\site-packages\mne\io\edf\edf.py:996: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   etmode = np.fromstring(etmode, np.uint8).tolist()[0]
# C:\Users\kings\Anaconda3\envs\mne\lib\site-packages\mne\io\edf\edf.py:996: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   etmode = np.fromstring(etmode, np.uint8).tolist()[0]
# C:\Users\kings\Anaconda3\envs\mne\lib\site-packages\mne\io\edf\edf.py:996: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   etmode = np.fromstring(etmode, np.uint8).tolist()[0]
# C:\Users\kings\Anaconda3\envs\mne\lib\site-packages\mne\io\edf\edf.py:996: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   etmode = np.fromstring(etmode, np.uint8).tolist()[0]
# C:\Users\kings\Anaconda3\envs\mne\lib\site-packages\mne\io\edf\edf.py:996: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   etmode = np.fromstring(etmode, np.uint8).tolist()[0]
# C:\Users\kings\Anaconda3\envs\mne\lib\site-packages\mne\io\edf\edf.py:996: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   etmode = np.fromstring(etmode, np.uint8).tolist()[0]
# C:\Users\kings\Anaconda3\envs\mne\lib\site-packages\mne\io\edf\edf.py:996: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   etmode = np.fromstring(etmode, np.uint8).tolist()[0]
# C:\Users\kings\Anaconda3\envs\mne\lib\site-packages\mne\io\edf\edf.py:996: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   etmode = np.fromstring(etmode, np.uint8).tolist()[0]
# C:\Users\kings\Anaconda3\envs\mne\lib\site-packages\mne\io\edf\edf.py:996: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   etmode = np.fromstring(etmode, np.uint8).tolist()[0]
# C:\Users\kings\Anaconda3\envs\mne\lib\site-packages\mne\io\edf\edf.py:996: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   etmode = np.fromstring(etmode, np.uint8).tolist()[0]
# C:\Users\kings\Anaconda3\envs\mne\lib\site-packages\mne\io\edf\edf.py:996: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   etmode = np.fromstring(etmode, np.uint8).tolist()[0]
# C:\Users\kings\Anaconda3\envs\mne\lib\site-packages\mne\io\edf\edf.py:996: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   etmode = np.fromstring(etmode, np.uint8).tolist()[0]
# C:\Users\kings\Anaconda3\envs\mne\lib\site-packages\mne\io\edf\edf.py:996: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   etmode = np.fromstring(etmode, np.uint8).tolist()[0]
# C:\Users\kings\Anaconda3\envs\mne\lib\site-packages\mne\io\edf\edf.py:996: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   etmode = np.fromstring(etmode, np.uint8).tolist()[0]
# C:\Users\kings\Anaconda3\envs\mne\lib\site-packages\mne\io\edf\edf.py:996: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   etmode = np.fromstring(etmode, np.uint8).tolist()[0]
# C:\Users\kings\Anaconda3\envs\mne\lib\site-packages\mne\io\edf\edf.py:996: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   etmode = np.fromstring(etmode, np.uint8).tolist()[0]
# C:\Users\kings\Anaconda3\envs\mne\lib\site-packages\mne\io\edf\edf.py:996: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   etmode = np.fromstring(etmode, np.uint8).tolist()[0]
# C:\Users\kings\Anaconda3\envs\mne\lib\site-packages\mne\io\edf\edf.py:996: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   etmode = np.fromstring(etmode, np.uint8).tolist()[0]
# C:\Users\kings\Anaconda3\envs\mne\lib\site-packages\mne\io\edf\edf.py:996: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   etmode = np.fromstring(etmode, np.uint8).tolist()[0]
# C:\Users\kings\Anaconda3\envs\mne\lib\site-packages\mne\io\edf\edf.py:996: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   etmode = np.fromstring(etmode, np.uint8).tolist()[0]
# C:\Users\kings\Anaconda3\envs\mne\lib\site-packages\mne\io\edf\edf.py:996: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   etmode = np.fromstring(etmode, np.uint8).tolist()[0]
# C:\Users\kings\Anaconda3\envs\mne\lib\site-packages\mne\io\edf\edf.py:996: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   etmode = np.fromstring(etmode, np.uint8).tolist()[0]
# C:\Users\kings\Anaconda3\envs\mne\lib\site-packages\mne\io\edf\edf.py:996: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   etmode = np.fromstring(etmode, np.uint8).tolist()[0]
# C:\Users\kings\Anaconda3\envs\mne\lib\site-packages\mne\io\edf\edf.py:996: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   etmode = np.fromstring(etmode, np.uint8).tolist()[0]
# C:\Users\kings\Anaconda3\envs\mne\lib\site-packages\mne\io\edf\edf.py:996: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   etmode = np.fromstring(etmode, np.uint8).tolist()[0]
# C:\Users\kings\Anaconda3\envs\mne\lib\site-packages\mne\io\edf\edf.py:996: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   etmode = np.fromstring(etmode, np.uint8).tolist()[0]
# C:\Users\kings\Anaconda3\envs\mne\lib\site-packages\mne\io\edf\edf.py:996: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   etmode = np.fromstring(etmode, np.uint8).tolist()[0]
# C:\Users\kings\Anaconda3\envs\mne\lib\site-packages\mne\io\edf\edf.py:996: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   etmode = np.fromstring(etmode, np.uint8).tolist()[0]
# C:\Users\kings\Anaconda3\envs\mne\lib\site-packages\mne\io\edf\edf.py:996: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   etmode = np.fromstring(etmode, np.uint8).tolist()[0]
# C:\Users\kings\Anaconda3\envs\mne\lib\site-packages\mne\io\edf\edf.py:996: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   etmode = np.fromstring(etmode, np.uint8).tolist()[0]
# C:\Users\kings\Anaconda3\envs\mne\lib\site-packages\mne\io\edf\edf.py:996: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   etmode = np.fromstring(etmode, np.uint8).tolist()[0]
# C:\Users\kings\Anaconda3\envs\mne\lib\site-packages\mne\io\edf\edf.py:996: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   etmode = np.fromstring(etmode, np.uint8).tolist()[0]
# C:\Users\kings\Anaconda3\envs\mne\lib\site-packages\mne\io\edf\edf.py:996: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   etmode = np.fromstring(etmode, np.uint8).tolist()[0]

# %%
print(len(files))
# Out:
# 90

# %%
eventDescription_offline_paradigm = {
    '768': "trial start",
    '785': "beep",
    '786': "fixation cross",
    '776': "supinationclass cue",
    '777': "pronationclass cue",
    '779': "hand openclass cue",
    '925': "palmar graspclass cue",
    '926': "ateral graspclass cue",
}
# narrow it down to two
# eventDescription_offline_paradigm = {
#     '776': "supinationclass cue",
#     '777': "pronationclass cue",
# }

# %%
# events = [number of events, position, event code, channel, duration]
# file_P01_Run3._raw_extras[0]['events']
event_id = {}
epochs_list = []
for file in files:
    event, _ = mne.events_from_annotations(file)


    # build event id and filter 1-7 id

    contains_both = 0
    for i in _: #handle event_id
        if i not in eventDescription_offline_paradigm:
            continue
        contains_both += 1
        event_id[eventDescription_offline_paradigm[i]] = _[i]


    print(f'event id: {event_id}')
    if contains_both == len(eventDescription_offline_paradigm):
        epochs = mne.Epochs(file, event, event_id, tmin=-0., tmax=1, baseline=None, event_repeated = 'merge', preload=True)

        epochs_list.append(epochs)

result_epochs = mne.concatenate_epochs(epochs_list)
# Out:
# Used Annotations descriptions: ['33536', '768', '785']
# event id: {'trial start': 2, 'beep': 3}
# Used Annotations descriptions: ['33536', '33554', '768', '785', '786']
# event id: {'trial start': 3, 'beep': 4, 'fixation cross': 5}
# Used Annotations descriptions: ['33536', '33544', '33545', '33547', '33554', '33693', '33694', '768', '776', '777', '779', '785', '786', '925', '926']
# event id: {'trial start': 8, 'beep': 12, 'fixation cross': 13, 'supinationclass cue': 9, 'pronationclass cue': 10, 'hand openclass cue': 11, 'palmar graspclass cue': 14, 'ateral graspclass cue': 15}
# Not setting metadata
# Multiple event values for single event times found. Creating new event value to reflect simultaneous events.
# Not setting metadata
# 80 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 80 events and 257 original time points ...
# 0 bad epochs dropped
# Used Annotations descriptions: ['33536', '33544', '33545', '33547', '33554', '33693', '33694', '768', '776', '777', '779', '785', '786', '925', '926']
# event id: {'trial start': 8, 'beep': 12, 'fixation cross': 13, 'supinationclass cue': 9, 'pronationclass cue': 10, 'hand openclass cue': 11, 'palmar graspclass cue': 14, 'ateral graspclass cue': 15}
# Not setting metadata
# Multiple event values for single event times found. Creating new event value to reflect simultaneous events.
# Not setting metadata
# 80 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 80 events and 257 original time points ...
# 0 bad epochs dropped
# Used Annotations descriptions: ['33536', '33544', '33545', '33547', '33554', '33693', '33694', '768', '776', '777', '779', '785', '786', '925', '926']
# event id: {'trial start': 8, 'beep': 12, 'fixation cross': 13, 'supinationclass cue': 9, 'pronationclass cue': 10, 'hand openclass cue': 11, 'palmar graspclass cue': 14, 'ateral graspclass cue': 15}
# Not setting metadata
# Multiple event values for single event times found. Creating new event value to reflect simultaneous events.
# Not setting metadata
# 80 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 80 events and 257 original time points ...
# 0 bad epochs dropped
# Used Annotations descriptions: ['33536', '33544', '33545', '33547', '33554', '33693', '33694', '768', '776', '777', '779', '785', '786', '925', '926']
# event id: {'trial start': 8, 'beep': 12, 'fixation cross': 13, 'supinationclass cue': 9, 'pronationclass cue': 10, 'hand openclass cue': 11, 'palmar graspclass cue': 14, 'ateral graspclass cue': 15}
# Not setting metadata
# Multiple event values for single event times found. Creating new event value to reflect simultaneous events.
# Not setting metadata
# 80 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 80 events and 257 original time points ...
# 0 bad epochs dropped
# Used Annotations descriptions: ['33536', '33544', '33545', '33547', '33554', '33693', '33694', '768', '776', '777', '779', '785', '786', '925', '926']
# event id: {'trial start': 8, 'beep': 12, 'fixation cross': 13, 'supinationclass cue': 9, 'pronationclass cue': 10, 'hand openclass cue': 11, 'palmar graspclass cue': 14, 'ateral graspclass cue': 15}
# Not setting metadata
# Multiple event values for single event times found. Creating new event value to reflect simultaneous events.
# Not setting metadata
# 80 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 80 events and 257 original time points ...
# 0 bad epochs dropped
# Used Annotations descriptions: ['33536', '768', '785']
# event id: {'trial start': 2, 'beep': 3, 'fixation cross': 13, 'supinationclass cue': 9, 'pronationclass cue': 10, 'hand openclass cue': 11, 'palmar graspclass cue': 14, 'ateral graspclass cue': 15}
# Used Annotations descriptions: ['33536', '33554', '768', '785', '786']
# event id: {'trial start': 3, 'beep': 4, 'fixation cross': 5, 'supinationclass cue': 9, 'pronationclass cue': 10, 'hand openclass cue': 11, 'palmar graspclass cue': 14, 'ateral graspclass cue': 15}
# Used Annotations descriptions: ['33536', '33544', '33545', '33547', '33554', '33693', '33694', '768', '776', '777', '779', '785', '786', '925', '926']
# event id: {'trial start': 8, 'beep': 12, 'fixation cross': 13, 'supinationclass cue': 9, 'pronationclass cue': 10, 'hand openclass cue': 11, 'palmar graspclass cue': 14, 'ateral graspclass cue': 15}
# Not setting metadata
# Multiple event values for single event times found. Creating new event value to reflect simultaneous events.
# Not setting metadata
# 80 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 80 events and 257 original time points ...
# 0 bad epochs dropped
# Used Annotations descriptions: ['33536', '33544', '33545', '33547', '33554', '33693', '33694', '768', '776', '777', '779', '785', '786', '925', '926']
# event id: {'trial start': 8, 'beep': 12, 'fixation cross': 13, 'supinationclass cue': 9, 'pronationclass cue': 10, 'hand openclass cue': 11, 'palmar graspclass cue': 14, 'ateral graspclass cue': 15}
# Not setting metadata
# Multiple event values for single event times found. Creating new event value to reflect simultaneous events.
# Not setting metadata
# 80 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 80 events and 257 original time points ...
# 0 bad epochs dropped
# Used Annotations descriptions: ['33536', '33544', '33545', '33547', '33554', '33693', '33694', '768', '776', '777', '779', '785', '786', '925', '926']
# event id: {'trial start': 8, 'beep': 12, 'fixation cross': 13, 'supinationclass cue': 9, 'pronationclass cue': 10, 'hand openclass cue': 11, 'palmar graspclass cue': 14, 'ateral graspclass cue': 15}
# Not setting metadata
# Multiple event values for single event times found. Creating new event value to reflect simultaneous events.
# Not setting metadata
# 80 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 80 events and 257 original time points ...
# 0 bad epochs dropped
# Used Annotations descriptions: ['33536', '33544', '33545', '33547', '33554', '33693', '33694', '768', '776', '777', '779', '785', '786', '925', '926']
# event id: {'trial start': 8, 'beep': 12, 'fixation cross': 13, 'supinationclass cue': 9, 'pronationclass cue': 10, 'hand openclass cue': 11, 'palmar graspclass cue': 14, 'ateral graspclass cue': 15}
# Not setting metadata
# Multiple event values for single event times found. Creating new event value to reflect simultaneous events.
# Not setting metadata
# 80 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 80 events and 257 original time points ...
# 0 bad epochs dropped
# Used Annotations descriptions: ['33536', '768', '785']
# event id: {'trial start': 2, 'beep': 3, 'fixation cross': 13, 'supinationclass cue': 9, 'pronationclass cue': 10, 'hand openclass cue': 11, 'palmar graspclass cue': 14, 'ateral graspclass cue': 15}
# Used Annotations descriptions: ['33536', '33554', '768', '785', '786']
# event id: {'trial start': 3, 'beep': 4, 'fixation cross': 5, 'supinationclass cue': 9, 'pronationclass cue': 10, 'hand openclass cue': 11, 'palmar graspclass cue': 14, 'ateral graspclass cue': 15}
# Used Annotations descriptions: ['33536', '768', '785']
# event id: {'trial start': 2, 'beep': 3, 'fixation cross': 5, 'supinationclass cue': 9, 'pronationclass cue': 10, 'hand openclass cue': 11, 'palmar graspclass cue': 14, 'ateral graspclass cue': 15}
# Used Annotations descriptions: ['33536', '33554', '768', '785', '786']
# event id: {'trial start': 3, 'beep': 4, 'fixation cross': 5, 'supinationclass cue': 9, 'pronationclass cue': 10, 'hand openclass cue': 11, 'palmar graspclass cue': 14, 'ateral graspclass cue': 15}
# Used Annotations descriptions: ['33536', '33544', '33545', '33547', '33554', '33693', '33694', '768', '776', '777', '779', '785', '786', '925', '926']
# event id: {'trial start': 8, 'beep': 12, 'fixation cross': 13, 'supinationclass cue': 9, 'pronationclass cue': 10, 'hand openclass cue': 11, 'palmar graspclass cue': 14, 'ateral graspclass cue': 15}
# Not setting metadata
# Multiple event values for single event times found. Creating new event value to reflect simultaneous events.
# Not setting metadata
# 80 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 80 events and 257 original time points ...
# 0 bad epochs dropped
# Used Annotations descriptions: ['33536', '33544', '33545', '33547', '33554', '33693', '33694', '768', '776', '777', '779', '785', '786', '925', '926']
# event id: {'trial start': 8, 'beep': 12, 'fixation cross': 13, 'supinationclass cue': 9, 'pronationclass cue': 10, 'hand openclass cue': 11, 'palmar graspclass cue': 14, 'ateral graspclass cue': 15}
# Not setting metadata
# Multiple event values for single event times found. Creating new event value to reflect simultaneous events.
# Not setting metadata
# 80 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 80 events and 257 original time points ...
# 0 bad epochs dropped
# Used Annotations descriptions: ['33536', '33544', '33545', '33547', '33554', '33693', '33694', '768', '776', '777', '779', '785', '786', '925', '926']
# event id: {'trial start': 8, 'beep': 12, 'fixation cross': 13, 'supinationclass cue': 9, 'pronationclass cue': 10, 'hand openclass cue': 11, 'palmar graspclass cue': 14, 'ateral graspclass cue': 15}
# Not setting metadata
# Multiple event values for single event times found. Creating new event value to reflect simultaneous events.
# Not setting metadata
# 80 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 80 events and 257 original time points ...
# 0 bad epochs dropped
# Used Annotations descriptions: ['33536', '33544', '33545', '33547', '33554', '33693', '33694', '768', '776', '777', '779', '785', '786', '925', '926']
# event id: {'trial start': 8, 'beep': 12, 'fixation cross': 13, 'supinationclass cue': 9, 'pronationclass cue': 10, 'hand openclass cue': 11, 'palmar graspclass cue': 14, 'ateral graspclass cue': 15}
# Not setting metadata
# Multiple event values for single event times found. Creating new event value to reflect simultaneous events.
# Not setting metadata
# 80 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 80 events and 257 original time points ...
# 0 bad epochs dropped
# Used Annotations descriptions: ['33536', '33544', '33545', '33547', '33554', '33693', '33694', '768', '776', '777', '779', '785', '786', '925', '926']
# event id: {'trial start': 8, 'beep': 12, 'fixation cross': 13, 'supinationclass cue': 9, 'pronationclass cue': 10, 'hand openclass cue': 11, 'palmar graspclass cue': 14, 'ateral graspclass cue': 15}
# Not setting metadata
# Multiple event values for single event times found. Creating new event value to reflect simultaneous events.
# Not setting metadata
# 80 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 80 events and 257 original time points ...
# 0 bad epochs dropped
# Used Annotations descriptions: ['33536', '768', '785']
# event id: {'trial start': 2, 'beep': 3, 'fixation cross': 13, 'supinationclass cue': 9, 'pronationclass cue': 10, 'hand openclass cue': 11, 'palmar graspclass cue': 14, 'ateral graspclass cue': 15}
# Used Annotations descriptions: ['33536', '33554', '768', '785', '786']
# event id: {'trial start': 3, 'beep': 4, 'fixation cross': 5, 'supinationclass cue': 9, 'pronationclass cue': 10, 'hand openclass cue': 11, 'palmar graspclass cue': 14, 'ateral graspclass cue': 15}
# Used Annotations descriptions: ['33536', '33544', '33545', '33547', '33554', '33693', '33694', '768', '776', '777', '779', '785', '786', '925', '926']
# event id: {'trial start': 8, 'beep': 12, 'fixation cross': 13, 'supinationclass cue': 9, 'pronationclass cue': 10, 'hand openclass cue': 11, 'palmar graspclass cue': 14, 'ateral graspclass cue': 15}
# Not setting metadata
# Multiple event values for single event times found. Creating new event value to reflect simultaneous events.
# Not setting metadata
# 80 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 80 events and 257 original time points ...
# 0 bad epochs dropped
# Used Annotations descriptions: ['33536', '33544', '33545', '33547', '33554', '33693', '33694', '768', '776', '777', '779', '785', '786', '925', '926']
# event id: {'trial start': 8, 'beep': 12, 'fixation cross': 13, 'supinationclass cue': 9, 'pronationclass cue': 10, 'hand openclass cue': 11, 'palmar graspclass cue': 14, 'ateral graspclass cue': 15}
# Not setting metadata
# Multiple event values for single event times found. Creating new event value to reflect simultaneous events.
# Not setting metadata
# 80 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 80 events and 257 original time points ...
# 0 bad epochs dropped
# Used Annotations descriptions: ['33536', '33544', '33545', '33547', '33554', '33693', '33694', '768', '776', '777', '779', '785', '786', '925', '926']
# event id: {'trial start': 8, 'beep': 12, 'fixation cross': 13, 'supinationclass cue': 9, 'pronationclass cue': 10, 'hand openclass cue': 11, 'palmar graspclass cue': 14, 'ateral graspclass cue': 15}
# Not setting metadata
# Multiple event values for single event times found. Creating new event value to reflect simultaneous events.
# Not setting metadata
# 80 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 80 events and 257 original time points ...
# 0 bad epochs dropped
# Used Annotations descriptions: ['33536', '33544', '33545', '33547', '33554', '33693', '33694', '768', '776', '777', '779', '785', '786', '925', '926']
# event id: {'trial start': 8, 'beep': 12, 'fixation cross': 13, 'supinationclass cue': 9, 'pronationclass cue': 10, 'hand openclass cue': 11, 'palmar graspclass cue': 14, 'ateral graspclass cue': 15}
# Not setting metadata
# Multiple event values for single event times found. Creating new event value to reflect simultaneous events.
# Not setting metadata
# 80 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 80 events and 257 original time points ...
# 0 bad epochs dropped
# Used Annotations descriptions: ['33536', '768', '785']
# event id: {'trial start': 2, 'beep': 3, 'fixation cross': 13, 'supinationclass cue': 9, 'pronationclass cue': 10, 'hand openclass cue': 11, 'palmar graspclass cue': 14, 'ateral graspclass cue': 15}
# Used Annotations descriptions: ['33536', '33554', '768', '785', '786']
# event id: {'trial start': 3, 'beep': 4, 'fixation cross': 5, 'supinationclass cue': 9, 'pronationclass cue': 10, 'hand openclass cue': 11, 'palmar graspclass cue': 14, 'ateral graspclass cue': 15}
# Used Annotations descriptions: ['33536', '768', '785']
# event id: {'trial start': 2, 'beep': 3, 'fixation cross': 5, 'supinationclass cue': 9, 'pronationclass cue': 10, 'hand openclass cue': 11, 'palmar graspclass cue': 14, 'ateral graspclass cue': 15}
# Used Annotations descriptions: ['33536', '33554', '768', '785', '786']
# event id: {'trial start': 3, 'beep': 4, 'fixation cross': 5, 'supinationclass cue': 9, 'pronationclass cue': 10, 'hand openclass cue': 11, 'palmar graspclass cue': 14, 'ateral graspclass cue': 15}
# Used Annotations descriptions: ['33536', '33544', '33545', '33547', '33554', '33693', '33694', '768', '776', '777', '779', '785', '786', '925', '926']
# event id: {'trial start': 8, 'beep': 12, 'fixation cross': 13, 'supinationclass cue': 9, 'pronationclass cue': 10, 'hand openclass cue': 11, 'palmar graspclass cue': 14, 'ateral graspclass cue': 15}
# Not setting metadata
# Multiple event values for single event times found. Creating new event value to reflect simultaneous events.
# Not setting metadata
# 80 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 80 events and 257 original time points ...
# 0 bad epochs dropped
# Used Annotations descriptions: ['33536', '33544', '33545', '33547', '33554', '33693', '33694', '768', '776', '777', '779', '785', '786', '925', '926']
# event id: {'trial start': 8, 'beep': 12, 'fixation cross': 13, 'supinationclass cue': 9, 'pronationclass cue': 10, 'hand openclass cue': 11, 'palmar graspclass cue': 14, 'ateral graspclass cue': 15}
# Not setting metadata
# Multiple event values for single event times found. Creating new event value to reflect simultaneous events.
# Not setting metadata
# 80 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 80 events and 257 original time points ...
# 0 bad epochs dropped
# Used Annotations descriptions: ['33536', '33544', '33545', '33547', '33554', '33693', '33694', '768', '776', '777', '779', '785', '786', '925', '926']
# event id: {'trial start': 8, 'beep': 12, 'fixation cross': 13, 'supinationclass cue': 9, 'pronationclass cue': 10, 'hand openclass cue': 11, 'palmar graspclass cue': 14, 'ateral graspclass cue': 15}
# Not setting metadata
# Multiple event values for single event times found. Creating new event value to reflect simultaneous events.
# Not setting metadata
# 80 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 80 events and 257 original time points ...
# 0 bad epochs dropped
# Used Annotations descriptions: ['33536', '33544', '33545', '33547', '33554', '33693', '33694', '768', '776', '777', '779', '785', '786', '925', '926']
# event id: {'trial start': 8, 'beep': 12, 'fixation cross': 13, 'supinationclass cue': 9, 'pronationclass cue': 10, 'hand openclass cue': 11, 'palmar graspclass cue': 14, 'ateral graspclass cue': 15}
# Not setting metadata
# Multiple event values for single event times found. Creating new event value to reflect simultaneous events.
# Not setting metadata
# 80 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 80 events and 257 original time points ...
# 0 bad epochs dropped
# Used Annotations descriptions: ['33536', '33544', '33545', '33547', '33554', '33693', '33694', '768', '776', '777', '779', '785', '786', '925', '926']
# event id: {'trial start': 8, 'beep': 12, 'fixation cross': 13, 'supinationclass cue': 9, 'pronationclass cue': 10, 'hand openclass cue': 11, 'palmar graspclass cue': 14, 'ateral graspclass cue': 15}
# Not setting metadata
# Multiple event values for single event times found. Creating new event value to reflect simultaneous events.
# Not setting metadata
# 80 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 80 events and 257 original time points ...
# 0 bad epochs dropped
# Used Annotations descriptions: ['33536', '768', '785']
# event id: {'trial start': 2, 'beep': 3, 'fixation cross': 13, 'supinationclass cue': 9, 'pronationclass cue': 10, 'hand openclass cue': 11, 'palmar graspclass cue': 14, 'ateral graspclass cue': 15}
# Used Annotations descriptions: ['33536', '33554', '768', '785', '786']
# event id: {'trial start': 3, 'beep': 4, 'fixation cross': 5, 'supinationclass cue': 9, 'pronationclass cue': 10, 'hand openclass cue': 11, 'palmar graspclass cue': 14, 'ateral graspclass cue': 15}
# Used Annotations descriptions: ['33536', '33544', '33545', '33547', '33554', '33693', '33694', '768', '776', '777', '779', '785', '786', '925', '926']
# event id: {'trial start': 8, 'beep': 12, 'fixation cross': 13, 'supinationclass cue': 9, 'pronationclass cue': 10, 'hand openclass cue': 11, 'palmar graspclass cue': 14, 'ateral graspclass cue': 15}
# Not setting metadata
# Multiple event values for single event times found. Creating new event value to reflect simultaneous events.
# Not setting metadata
# 80 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 80 events and 257 original time points ...
# 0 bad epochs dropped
# Used Annotations descriptions: ['33536', '33544', '33545', '33547', '33554', '33693', '33694', '768', '776', '777', '779', '785', '786', '925', '926']
# event id: {'trial start': 8, 'beep': 12, 'fixation cross': 13, 'supinationclass cue': 9, 'pronationclass cue': 10, 'hand openclass cue': 11, 'palmar graspclass cue': 14, 'ateral graspclass cue': 15}
# Not setting metadata
# Multiple event values for single event times found. Creating new event value to reflect simultaneous events.
# Not setting metadata
# 80 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 80 events and 257 original time points ...
# 0 bad epochs dropped
# Used Annotations descriptions: ['33536', '33544', '33545', '33547', '33554', '33693', '33694', '768', '776', '777', '779', '785', '786', '925', '926']
# event id: {'trial start': 8, 'beep': 12, 'fixation cross': 13, 'supinationclass cue': 9, 'pronationclass cue': 10, 'hand openclass cue': 11, 'palmar graspclass cue': 14, 'ateral graspclass cue': 15}
# Not setting metadata
# Multiple event values for single event times found. Creating new event value to reflect simultaneous events.
# Not setting metadata
# 80 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 80 events and 257 original time points ...
# 0 bad epochs dropped
# Used Annotations descriptions: ['33536', '33544', '33545', '33547', '33554', '33693', '33694', '768', '776', '777', '779', '785', '786', '925', '926']
# event id: {'trial start': 8, 'beep': 12, 'fixation cross': 13, 'supinationclass cue': 9, 'pronationclass cue': 10, 'hand openclass cue': 11, 'palmar graspclass cue': 14, 'ateral graspclass cue': 15}
# Not setting metadata
# Multiple event values for single event times found. Creating new event value to reflect simultaneous events.
# Not setting metadata
# 80 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 80 events and 257 original time points ...
# 0 bad epochs dropped
# Used Annotations descriptions: ['33536', '768', '785']
# event id: {'trial start': 2, 'beep': 3, 'fixation cross': 13, 'supinationclass cue': 9, 'pronationclass cue': 10, 'hand openclass cue': 11, 'palmar graspclass cue': 14, 'ateral graspclass cue': 15}
# Used Annotations descriptions: ['33536', '33554', '768', '785', '786']
# event id: {'trial start': 3, 'beep': 4, 'fixation cross': 5, 'supinationclass cue': 9, 'pronationclass cue': 10, 'hand openclass cue': 11, 'palmar graspclass cue': 14, 'ateral graspclass cue': 15}
# Used Annotations descriptions: ['33536', '768', '785']
# event id: {'trial start': 2, 'beep': 3, 'fixation cross': 5, 'supinationclass cue': 9, 'pronationclass cue': 10, 'hand openclass cue': 11, 'palmar graspclass cue': 14, 'ateral graspclass cue': 15}
# Used Annotations descriptions: ['33536', '33554', '768', '785', '786']
# event id: {'trial start': 3, 'beep': 4, 'fixation cross': 5, 'supinationclass cue': 9, 'pronationclass cue': 10, 'hand openclass cue': 11, 'palmar graspclass cue': 14, 'ateral graspclass cue': 15}
# Used Annotations descriptions: ['33536', '33544', '33545', '33547', '33554', '33693', '33694', '768', '776', '777', '779', '785', '786', '925', '926']
# event id: {'trial start': 8, 'beep': 12, 'fixation cross': 13, 'supinationclass cue': 9, 'pronationclass cue': 10, 'hand openclass cue': 11, 'palmar graspclass cue': 14, 'ateral graspclass cue': 15}
# Not setting metadata
# Multiple event values for single event times found. Creating new event value to reflect simultaneous events.
# Not setting metadata
# 80 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 80 events and 257 original time points ...
# 0 bad epochs dropped
# Used Annotations descriptions: ['33536', '33544', '33545', '33547', '33554', '33693', '33694', '768', '776', '777', '779', '785', '786', '925', '926']
# event id: {'trial start': 8, 'beep': 12, 'fixation cross': 13, 'supinationclass cue': 9, 'pronationclass cue': 10, 'hand openclass cue': 11, 'palmar graspclass cue': 14, 'ateral graspclass cue': 15}
# Not setting metadata
# Multiple event values for single event times found. Creating new event value to reflect simultaneous events.
# Not setting metadata
# 80 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 80 events and 257 original time points ...
# 0 bad epochs dropped
# Used Annotations descriptions: ['33536', '33544', '33545', '33547', '33554', '33693', '33694', '768', '776', '777', '779', '785', '786', '925', '926']
# event id: {'trial start': 8, 'beep': 12, 'fixation cross': 13, 'supinationclass cue': 9, 'pronationclass cue': 10, 'hand openclass cue': 11, 'palmar graspclass cue': 14, 'ateral graspclass cue': 15}
# Not setting metadata
# Multiple event values for single event times found. Creating new event value to reflect simultaneous events.
# Not setting metadata
# 80 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 80 events and 257 original time points ...
# 0 bad epochs dropped
# Used Annotations descriptions: ['33536', '33544', '33545', '33547', '33554', '33693', '33694', '768', '776', '777', '779', '785', '786', '925', '926']
# event id: {'trial start': 8, 'beep': 12, 'fixation cross': 13, 'supinationclass cue': 9, 'pronationclass cue': 10, 'hand openclass cue': 11, 'palmar graspclass cue': 14, 'ateral graspclass cue': 15}
# Not setting metadata
# Multiple event values for single event times found. Creating new event value to reflect simultaneous events.
# Not setting metadata
# 80 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 80 events and 257 original time points ...
# 0 bad epochs dropped
# Used Annotations descriptions: ['33536', '33544', '33545', '33547', '33554', '33693', '33694', '768', '776', '777', '779', '785', '786', '925', '926']
# event id: {'trial start': 8, 'beep': 12, 'fixation cross': 13, 'supinationclass cue': 9, 'pronationclass cue': 10, 'hand openclass cue': 11, 'palmar graspclass cue': 14, 'ateral graspclass cue': 15}
# Not setting metadata
# Multiple event values for single event times found. Creating new event value to reflect simultaneous events.
# Not setting metadata
# 80 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 80 events and 257 original time points ...
# 0 bad epochs dropped
# Used Annotations descriptions: ['33536', '768', '785']
# event id: {'trial start': 2, 'beep': 3, 'fixation cross': 13, 'supinationclass cue': 9, 'pronationclass cue': 10, 'hand openclass cue': 11, 'palmar graspclass cue': 14, 'ateral graspclass cue': 15}
# Used Annotations descriptions: ['33536', '33554', '768', '785', '786']
# event id: {'trial start': 3, 'beep': 4, 'fixation cross': 5, 'supinationclass cue': 9, 'pronationclass cue': 10, 'hand openclass cue': 11, 'palmar graspclass cue': 14, 'ateral graspclass cue': 15}
# Used Annotations descriptions: ['33536', '33544', '33545', '33547', '33554', '33693', '33694', '768', '776', '777', '779', '785', '786', '925', '926']
# event id: {'trial start': 8, 'beep': 12, 'fixation cross': 13, 'supinationclass cue': 9, 'pronationclass cue': 10, 'hand openclass cue': 11, 'palmar graspclass cue': 14, 'ateral graspclass cue': 15}
# Not setting metadata
# Multiple event values for single event times found. Creating new event value to reflect simultaneous events.
# Not setting metadata
# 80 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 80 events and 257 original time points ...
# 0 bad epochs dropped
# Used Annotations descriptions: ['33536', '33544', '33545', '33547', '33554', '33693', '33694', '768', '776', '777', '779', '785', '786', '925', '926']
# event id: {'trial start': 8, 'beep': 12, 'fixation cross': 13, 'supinationclass cue': 9, 'pronationclass cue': 10, 'hand openclass cue': 11, 'palmar graspclass cue': 14, 'ateral graspclass cue': 15}
# Not setting metadata
# Multiple event values for single event times found. Creating new event value to reflect simultaneous events.
# Not setting metadata
# 80 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 80 events and 257 original time points ...
# 0 bad epochs dropped
# Used Annotations descriptions: ['33536', '33544', '33545', '33547', '33554', '33693', '33694', '768', '776', '777', '779', '785', '786', '925', '926']
# event id: {'trial start': 8, 'beep': 12, 'fixation cross': 13, 'supinationclass cue': 9, 'pronationclass cue': 10, 'hand openclass cue': 11, 'palmar graspclass cue': 14, 'ateral graspclass cue': 15}
# Not setting metadata
# Multiple event values for single event times found. Creating new event value to reflect simultaneous events.
# Not setting metadata
# 80 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 80 events and 257 original time points ...
# 0 bad epochs dropped
# Used Annotations descriptions: ['33536', '33544', '33545', '33547', '33554', '33693', '33694', '768', '776', '777', '779', '785', '786', '925', '926']
# event id: {'trial start': 8, 'beep': 12, 'fixation cross': 13, 'supinationclass cue': 9, 'pronationclass cue': 10, 'hand openclass cue': 11, 'palmar graspclass cue': 14, 'ateral graspclass cue': 15}
# Not setting metadata
# Multiple event values for single event times found. Creating new event value to reflect simultaneous events.
# Not setting metadata
# 80 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 80 events and 257 original time points ...
# 0 bad epochs dropped
# Used Annotations descriptions: ['33536', '768', '785']
# event id: {'trial start': 2, 'beep': 3, 'fixation cross': 13, 'supinationclass cue': 9, 'pronationclass cue': 10, 'hand openclass cue': 11, 'palmar graspclass cue': 14, 'ateral graspclass cue': 15}
# Used Annotations descriptions: ['33536', '33554', '768', '785', '786']
# event id: {'trial start': 3, 'beep': 4, 'fixation cross': 5, 'supinationclass cue': 9, 'pronationclass cue': 10, 'hand openclass cue': 11, 'palmar graspclass cue': 14, 'ateral graspclass cue': 15}
# Used Annotations descriptions: ['33536', '768', '785']
# event id: {'trial start': 2, 'beep': 3, 'fixation cross': 5, 'supinationclass cue': 9, 'pronationclass cue': 10, 'hand openclass cue': 11, 'palmar graspclass cue': 14, 'ateral graspclass cue': 15}
# Used Annotations descriptions: ['33536', '33554', '768', '785', '786']
# event id: {'trial start': 3, 'beep': 4, 'fixation cross': 5, 'supinationclass cue': 9, 'pronationclass cue': 10, 'hand openclass cue': 11, 'palmar graspclass cue': 14, 'ateral graspclass cue': 15}
# Used Annotations descriptions: ['33536', '33544', '33545', '33547', '33554', '33693', '33694', '768', '776', '777', '779', '785', '786', '925', '926']
# event id: {'trial start': 8, 'beep': 12, 'fixation cross': 13, 'supinationclass cue': 9, 'pronationclass cue': 10, 'hand openclass cue': 11, 'palmar graspclass cue': 14, 'ateral graspclass cue': 15}
# Not setting metadata
# Multiple event values for single event times found. Creating new event value to reflect simultaneous events.
# Not setting metadata
# 80 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 80 events and 257 original time points ...
# 0 bad epochs dropped
# Used Annotations descriptions: ['33536', '33544', '33545', '33547', '33554', '33693', '33694', '768', '776', '777', '779', '785', '786', '925', '926']
# event id: {'trial start': 8, 'beep': 12, 'fixation cross': 13, 'supinationclass cue': 9, 'pronationclass cue': 10, 'hand openclass cue': 11, 'palmar graspclass cue': 14, 'ateral graspclass cue': 15}
# Not setting metadata
# Multiple event values for single event times found. Creating new event value to reflect simultaneous events.
# Not setting metadata
# 80 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 80 events and 257 original time points ...
# 0 bad epochs dropped
# Used Annotations descriptions: ['33536', '33544', '33545', '33547', '33554', '33693', '33694', '768', '776', '777', '779', '785', '786', '925', '926']
# event id: {'trial start': 8, 'beep': 12, 'fixation cross': 13, 'supinationclass cue': 9, 'pronationclass cue': 10, 'hand openclass cue': 11, 'palmar graspclass cue': 14, 'ateral graspclass cue': 15}
# Not setting metadata
# Multiple event values for single event times found. Creating new event value to reflect simultaneous events.
# Not setting metadata
# 80 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 80 events and 257 original time points ...
# 0 bad epochs dropped
# Used Annotations descriptions: ['33536', '33544', '33545', '33547', '33554', '33693', '33694', '768', '776', '777', '779', '785', '786', '925', '926']
# event id: {'trial start': 8, 'beep': 12, 'fixation cross': 13, 'supinationclass cue': 9, 'pronationclass cue': 10, 'hand openclass cue': 11, 'palmar graspclass cue': 14, 'ateral graspclass cue': 15}
# Not setting metadata
# Multiple event values for single event times found. Creating new event value to reflect simultaneous events.
# Not setting metadata
# 80 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 80 events and 257 original time points ...
# 0 bad epochs dropped
# Used Annotations descriptions: ['33536', '33544', '33545', '33547', '33554', '33693', '33694', '768', '776', '777', '779', '785', '786', '925', '926']
# event id: {'trial start': 8, 'beep': 12, 'fixation cross': 13, 'supinationclass cue': 9, 'pronationclass cue': 10, 'hand openclass cue': 11, 'palmar graspclass cue': 14, 'ateral graspclass cue': 15}
# Not setting metadata
# Multiple event values for single event times found. Creating new event value to reflect simultaneous events.
# Not setting metadata
# 80 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 80 events and 257 original time points ...
# 0 bad epochs dropped
# Used Annotations descriptions: ['33536', '768', '785']
# event id: {'trial start': 2, 'beep': 3, 'fixation cross': 13, 'supinationclass cue': 9, 'pronationclass cue': 10, 'hand openclass cue': 11, 'palmar graspclass cue': 14, 'ateral graspclass cue': 15}
# Used Annotations descriptions: ['33536', '33554', '768', '785', '786']
# event id: {'trial start': 3, 'beep': 4, 'fixation cross': 5, 'supinationclass cue': 9, 'pronationclass cue': 10, 'hand openclass cue': 11, 'palmar graspclass cue': 14, 'ateral graspclass cue': 15}
# Used Annotations descriptions: ['33536', '33544', '33545', '33547', '33554', '33693', '33694', '768', '776', '777', '779', '785', '786', '925', '926']
# event id: {'trial start': 8, 'beep': 12, 'fixation cross': 13, 'supinationclass cue': 9, 'pronationclass cue': 10, 'hand openclass cue': 11, 'palmar graspclass cue': 14, 'ateral graspclass cue': 15}
# Not setting metadata
# Multiple event values for single event times found. Creating new event value to reflect simultaneous events.
# Not setting metadata
# 80 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 80 events and 257 original time points ...
# 0 bad epochs dropped
# Used Annotations descriptions: ['33536', '33544', '33545', '33547', '33554', '33693', '33694', '768', '776', '777', '779', '785', '786', '925', '926']
# event id: {'trial start': 8, 'beep': 12, 'fixation cross': 13, 'supinationclass cue': 9, 'pronationclass cue': 10, 'hand openclass cue': 11, 'palmar graspclass cue': 14, 'ateral graspclass cue': 15}
# Not setting metadata
# Multiple event values for single event times found. Creating new event value to reflect simultaneous events.
# Not setting metadata
# 80 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 80 events and 257 original time points ...
# 0 bad epochs dropped
# Used Annotations descriptions: ['33536', '33544', '33545', '33547', '33554', '33693', '33694', '768', '776', '777', '779', '785', '786', '925', '926']
# event id: {'trial start': 8, 'beep': 12, 'fixation cross': 13, 'supinationclass cue': 9, 'pronationclass cue': 10, 'hand openclass cue': 11, 'palmar graspclass cue': 14, 'ateral graspclass cue': 15}
# Not setting metadata
# Multiple event values for single event times found. Creating new event value to reflect simultaneous events.
# Not setting metadata
# 80 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 80 events and 257 original time points ...
# 0 bad epochs dropped
# Used Annotations descriptions: ['33536', '33544', '33545', '33547', '33554', '33693', '33694', '768', '776', '777', '779', '785', '786', '925', '926']
# event id: {'trial start': 8, 'beep': 12, 'fixation cross': 13, 'supinationclass cue': 9, 'pronationclass cue': 10, 'hand openclass cue': 11, 'palmar graspclass cue': 14, 'ateral graspclass cue': 15}
# Not setting metadata
# Multiple event values for single event times found. Creating new event value to reflect simultaneous events.
# Not setting metadata
# 80 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 80 events and 257 original time points ...
# 0 bad epochs dropped
# Used Annotations descriptions: ['33536', '768', '785']
# event id: {'trial start': 2, 'beep': 3, 'fixation cross': 13, 'supinationclass cue': 9, 'pronationclass cue': 10, 'hand openclass cue': 11, 'palmar graspclass cue': 14, 'ateral graspclass cue': 15}
# Used Annotations descriptions: ['33536', '33554', '768', '785', '786']
# event id: {'trial start': 3, 'beep': 4, 'fixation cross': 5, 'supinationclass cue': 9, 'pronationclass cue': 10, 'hand openclass cue': 11, 'palmar graspclass cue': 14, 'ateral graspclass cue': 15}
# Used Annotations descriptions: ['33536', '768', '785']
# event id: {'trial start': 2, 'beep': 3, 'fixation cross': 5, 'supinationclass cue': 9, 'pronationclass cue': 10, 'hand openclass cue': 11, 'palmar graspclass cue': 14, 'ateral graspclass cue': 15}
# Used Annotations descriptions: ['33536', '33554', '768', '785', '786']
# event id: {'trial start': 3, 'beep': 4, 'fixation cross': 5, 'supinationclass cue': 9, 'pronationclass cue': 10, 'hand openclass cue': 11, 'palmar graspclass cue': 14, 'ateral graspclass cue': 15}
# Used Annotations descriptions: ['33536', '33544', '33545', '33547', '33554', '33693', '33694', '768', '776', '777', '779', '785', '786', '925', '926']
# event id: {'trial start': 8, 'beep': 12, 'fixation cross': 13, 'supinationclass cue': 9, 'pronationclass cue': 10, 'hand openclass cue': 11, 'palmar graspclass cue': 14, 'ateral graspclass cue': 15}
# Not setting metadata
# Multiple event values for single event times found. Creating new event value to reflect simultaneous events.
# Not setting metadata
# 80 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 80 events and 257 original time points ...
# 0 bad epochs dropped
# Used Annotations descriptions: ['33536', '33544', '33545', '33547', '33554', '33693', '33694', '768', '776', '777', '779', '785', '786', '925', '926']
# event id: {'trial start': 8, 'beep': 12, 'fixation cross': 13, 'supinationclass cue': 9, 'pronationclass cue': 10, 'hand openclass cue': 11, 'palmar graspclass cue': 14, 'ateral graspclass cue': 15}
# Not setting metadata
# Multiple event values for single event times found. Creating new event value to reflect simultaneous events.
# Not setting metadata
# 80 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 80 events and 257 original time points ...
# 0 bad epochs dropped
# Used Annotations descriptions: ['33536', '33544', '33545', '33547', '33554', '33693', '33694', '768', '776', '777', '779', '785', '786', '925', '926']
# event id: {'trial start': 8, 'beep': 12, 'fixation cross': 13, 'supinationclass cue': 9, 'pronationclass cue': 10, 'hand openclass cue': 11, 'palmar graspclass cue': 14, 'ateral graspclass cue': 15}
# Not setting metadata
# Multiple event values for single event times found. Creating new event value to reflect simultaneous events.
# Not setting metadata
# 80 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 80 events and 257 original time points ...
# 0 bad epochs dropped
# Used Annotations descriptions: ['33536', '33544', '33545', '33547', '33554', '33693', '33694', '768', '776', '777', '779', '785', '786', '925', '926']
# event id: {'trial start': 8, 'beep': 12, 'fixation cross': 13, 'supinationclass cue': 9, 'pronationclass cue': 10, 'hand openclass cue': 11, 'palmar graspclass cue': 14, 'ateral graspclass cue': 15}
# Not setting metadata
# Multiple event values for single event times found. Creating new event value to reflect simultaneous events.
# Not setting metadata
# 80 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 80 events and 257 original time points ...
# 0 bad epochs dropped
# Used Annotations descriptions: ['33536', '33544', '33545', '33547', '33554', '33693', '33694', '768', '776', '777', '779', '785', '786', '925', '926']
# event id: {'trial start': 8, 'beep': 12, 'fixation cross': 13, 'supinationclass cue': 9, 'pronationclass cue': 10, 'hand openclass cue': 11, 'palmar graspclass cue': 14, 'ateral graspclass cue': 15}
# Not setting metadata
# Multiple event values for single event times found. Creating new event value to reflect simultaneous events.
# Not setting metadata
# 80 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 80 events and 257 original time points ...
# 0 bad epochs dropped
# Used Annotations descriptions: ['33536', '768', '785']
# event id: {'trial start': 2, 'beep': 3, 'fixation cross': 13, 'supinationclass cue': 9, 'pronationclass cue': 10, 'hand openclass cue': 11, 'palmar graspclass cue': 14, 'ateral graspclass cue': 15}
# Used Annotations descriptions: ['33536', '33554', '768', '785', '786']
# event id: {'trial start': 3, 'beep': 4, 'fixation cross': 5, 'supinationclass cue': 9, 'pronationclass cue': 10, 'hand openclass cue': 11, 'palmar graspclass cue': 14, 'ateral graspclass cue': 15}
# Used Annotations descriptions: ['33536', '33544', '33545', '33547', '33554', '33693', '33694', '768', '776', '777', '779', '785', '786', '925', '926']
# event id: {'trial start': 8, 'beep': 12, 'fixation cross': 13, 'supinationclass cue': 9, 'pronationclass cue': 10, 'hand openclass cue': 11, 'palmar graspclass cue': 14, 'ateral graspclass cue': 15}
# Not setting metadata
# Multiple event values for single event times found. Creating new event value to reflect simultaneous events.
# Not setting metadata
# 80 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 80 events and 257 original time points ...
# 0 bad epochs dropped
# Used Annotations descriptions: ['33536', '33544', '33545', '33547', '33554', '33693', '33694', '768', '776', '777', '779', '785', '786', '925', '926']
# event id: {'trial start': 8, 'beep': 12, 'fixation cross': 13, 'supinationclass cue': 9, 'pronationclass cue': 10, 'hand openclass cue': 11, 'palmar graspclass cue': 14, 'ateral graspclass cue': 15}
# Not setting metadata
# Multiple event values for single event times found. Creating new event value to reflect simultaneous events.
# Not setting metadata
# 80 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 80 events and 257 original time points ...
# 0 bad epochs dropped
# Used Annotations descriptions: ['33536', '33544', '33545', '33547', '33554', '33693', '33694', '768', '776', '777', '779', '785', '786', '925', '926']
# event id: {'trial start': 8, 'beep': 12, 'fixation cross': 13, 'supinationclass cue': 9, 'pronationclass cue': 10, 'hand openclass cue': 11, 'palmar graspclass cue': 14, 'ateral graspclass cue': 15}
# Not setting metadata
# Multiple event values for single event times found. Creating new event value to reflect simultaneous events.
# Not setting metadata
# 80 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 80 events and 257 original time points ...
# 0 bad epochs dropped
# Used Annotations descriptions: ['33536', '33544', '33545', '33547', '33554', '33693', '33694', '768', '776', '777', '779', '785', '786', '925', '926']
# event id: {'trial start': 8, 'beep': 12, 'fixation cross': 13, 'supinationclass cue': 9, 'pronationclass cue': 10, 'hand openclass cue': 11, 'palmar graspclass cue': 14, 'ateral graspclass cue': 15}
# Not setting metadata
# Multiple event values for single event times found. Creating new event value to reflect simultaneous events.
# Not setting metadata
# 80 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 80 events and 257 original time points ...
# 0 bad epochs dropped
# Used Annotations descriptions: ['33536', '768', '785']
# event id: {'trial start': 2, 'beep': 3, 'fixation cross': 13, 'supinationclass cue': 9, 'pronationclass cue': 10, 'hand openclass cue': 11, 'palmar graspclass cue': 14, 'ateral graspclass cue': 15}
# Used Annotations descriptions: ['33536', '33554', '768', '785', '786']
# event id: {'trial start': 3, 'beep': 4, 'fixation cross': 5, 'supinationclass cue': 9, 'pronationclass cue': 10, 'hand openclass cue': 11, 'palmar graspclass cue': 14, 'ateral graspclass cue': 15}
# Not setting metadata
# Not setting metadata
# 4320 matching events found
# No baseline correction applied
# 0 bad epochs dropped

# %%
print(len(set(event_id)))
#9, 10, 0
print(result_epochs.events)
# Out:
# 8
# [[   2560       0       1]
#  [   3072       0      10]
#  [   4409       0       1]
#  ...
#  [4097418       0      15]
#  [4098721       0       1]
#  [4099233       0      14]]

# %%
# 0: not supinationclass or pronationclass cue
labels = result_epochs.events[:,-1]
labels = np.array(list(map(lambda x:  0 if (not x == 9) and (not x == 10) else x, labels)))
print(labels)

# format: trials, channels, samples
X = result_epochs.get_data() * 100
y = labels

kernels, chans, samples = 1, 64, 257
# Out:
# [ 0 10  0 ...  0  0  0]

# %%
X.shape
# Out:
# (4320, 64, 257)

# %%
# Spliting dataset
X_train = X[0:2016,]
Y_train = y[0:2016]
X_validate = X[2016:2304,]
Y_validate = y[2016:2304]
X_test = X[2304:,]
Y_test = y[2304:]

print(Y_train)
# Out:
# [ 0 10  0 ...  9  0  0]

# %%
# Label Encode it first
encoder = LabelEncoder()
encoder.fit(Y_train)
Y_train = encoder.transform(Y_train)
Y_validate = encoder.transform(Y_validate)
Y_test = encoder.transform(Y_test)

# Convert label to one-hot encodings
Y_train = np_utils.to_categorical(Y_train)
Y_validate = np_utils.to_categorical(Y_validate)
Y_test = np_utils.to_categorical(Y_test)

#convert to (trials, kernels, channels, samples) format.
# contains 64 channels and 257 time-points. Set the number of kernels to 1.
X_train = X_train.reshape(X_train.shape[0], kernels, chans, samples)
X_validate = X_validate.reshape(X_validate.shape[0], kernels, chans, samples)
X_test = X_test.reshape(X_test.shape[0], kernels, chans, samples)

print('X_train shape:', X_train.shape)
print(X_train.shape[0], 'train samples')
print(X_test.shape[0], 'test samples')
# Out:
# X_train shape: (2016, 1, 64, 257)
# 2016 train samples
# 2016 test samples

# %%
# testing gpu
from tensorflow.python.client import device_lib
import os
os.environ["CUDA_VISIBLE_DEVICES"]="0"

def get_available_devices():
    local_device_protos = device_lib.list_local_devices()
    return [x.name for x in local_device_protos]

print(get_available_devices())
gpus = tf.config.experimental.list_physical_devices('GPU')
for physical_device in gpus:
    tf.config.experimental.set_memory_growth(physical_device, True)
# change the memory fraction as you want...import tensorflow as tf
# if gpus:
#     # Restrict TensorFlow to only allocate 1GB * 2 of memory on the first GPU
#     try:
#         tf.config.experimental.set_virtual_device_configuration(
#             gpus[0],
#             [tf.config.experimental.VirtualDeviceConfiguration(memory_limit=1024 * 2)])
#         logical_gpus = tf.config.experimental.list_logical_devices('GPU')
#         print(len(gpus), "Physical GPUs,", len(logical_gpus), "Logical GPUs")
#     except RuntimeError as e:
#         # Virtual devices must be set before GPUs have been initialized
#         print(e)
print(gpus)
# Out:
# ['/device:CPU:0', '/device:XLA_CPU:0', '/device:GPU:0', '/device:XLA_GPU:0']
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
# configure the EEGNet-8,2,16 model with kernel length of 257 samples (other
# model configurations may do better, but this is a good starting point)
model = EEGNet(nb_classes = 3, Chans = chans, Samples = samples,
               dropoutRate = 0.5, kernLength = 128, F1 = 8, D = 2, F2 = 16)
model.summary()
# Out:
# Model: "functional_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 1, 64, 257)]      0
# _________________________________________________________________
# conv2d (Conv2D)              (None, 8, 64, 257)        1024
# _________________________________________________________________
# batch_normalization (BatchNo (None, 8, 64, 257)        32
# _________________________________________________________________
# depthwise_conv2d (DepthwiseC (None, 16, 1, 257)        1024
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 16, 1, 257)        64
# _________________________________________________________________
# activation (Activation)      (None, 16, 1, 257)        0
# _________________________________________________________________
# average_pooling2d (AveragePo (None, 16, 1, 64)         0
# _________________________________________________________________
# separable_conv2d (SeparableC (None, 16, 1, 64)         512
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 16, 1, 64)         64
# _________________________________________________________________
# activation_1 (Activation)    (None, 16, 1, 64)         0
# _________________________________________________________________
# average_pooling2d_1 (Average (None, 16, 1, 8)          0
# _________________________________________________________________
# dropout (Dropout)            (None, 16, 1, 8)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 128)               0
# _________________________________________________________________
# dense (Dense)                (None, 3)                 387
# _________________________________________________________________
# softmax (Activation)         (None, 3)                 0
# =================================================================
# Total params: 3,107
# Trainable params: 3,027
# Non-trainable params: 80
# _________________________________________________________________

# %%
# compile the model and set the optimizers
model.compile(loss='categorical_crossentropy', optimizer='adam',
              metrics = ['accuracy'])

# count number of parameters in the model
numParams    = model.count_params()

# set a valid path for your system to record model checkpoints
checkpointer = ModelCheckpoint(filepath='./checkpoint.h5', verbose=1,
                               save_best_only=True)

# %%
# add callback
losses = []
accs = []
class LossAndAccRecord(Callback):
    def on_batch_end(self, batch, logs=None):
        losses.append(logs["loss"])
        accs.append(logs["accuracy"])


    def on_epoch_end(self, epoch, logs=None):
        pass

# %%
# the syntax is {class_1:weight_1, class_2:weight_2,...}. Here just setting
# the weights all to be 1
# unused
class_weights = {0:1, 1:1, 2:1, 3:1}
with tf.device('/device:GPU:0'):
    fittedModel = model.fit(X_train, Y_train, batch_size = 16, epochs = 50,
                        verbose = 1, validation_data=(X_validate, Y_validate),
                        callbacks=[checkpointer, LossAndAccRecord()])
# Out:
# Epoch 1/50
#   1/126 [..............................] - ETA: 0s - loss: 1.6231 - accuracy: 0.2500WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0020s vs `on_train_batch_end` time: 0.0040s). Check your callbacks.
# 126/126 [==============================] - ETA: 0s - loss: 0.7743 - accuracy: 0.7555
# Epoch 00001: val_loss improved from inf to 0.81767, saving model to .\checkpoint.h5
# 126/126 [==============================] - 1s 7ms/step - loss: 0.7743 - accuracy: 0.7555 - val_loss: 0.8177 - val_accuracy: 0.7882
# Epoch 2/50
# 122/126 [============================>.] - ETA: 0s - loss: 0.6634 - accuracy: 0.7987
# Epoch 00002: val_loss improved from 0.81767 to 0.72819, saving model to .\checkpoint.h5
# 126/126 [==============================] - 1s 5ms/step - loss: 0.6591 - accuracy: 0.8006 - val_loss: 0.7282 - val_accuracy: 0.7882
# Epoch 3/50
# 122/126 [============================>.] - ETA: 0s - loss: 0.6551 - accuracy: 0.8002
# Epoch 00003: val_loss improved from 0.72819 to 0.68002, saving model to .\checkpoint.h5
# 126/126 [==============================] - 1s 6ms/step - loss: 0.6540 - accuracy: 0.8001 - val_loss: 0.6800 - val_accuracy: 0.7882
# Epoch 4/50
# 118/126 [===========================>..] - ETA: 0s - loss: 0.6527 - accuracy: 0.7982
# Epoch 00004: val_loss did not improve from 0.68002
# 126/126 [==============================] - 1s 6ms/step - loss: 0.6476 - accuracy: 0.8006 - val_loss: 0.6939 - val_accuracy: 0.7882
# Epoch 5/50
# 124/126 [============================>.] - ETA: 0s - loss: 0.6378 - accuracy: 0.7979
# Epoch 00005: val_loss did not improve from 0.68002
# 126/126 [==============================] - 1s 6ms/step - loss: 0.6363 - accuracy: 0.7986 - val_loss: 0.7569 - val_accuracy: 0.7431
# Epoch 6/50
# 126/126 [==============================] - ETA: 0s - loss: 0.6230 - accuracy: 0.8006
# Epoch 00006: val_loss did not improve from 0.68002
# 126/126 [==============================] - 1s 6ms/step - loss: 0.6230 - accuracy: 0.8006 - val_loss: 0.6926 - val_accuracy: 0.7882
# Epoch 7/50
# 121/126 [===========================>..] - ETA: 0s - loss: 0.6200 - accuracy: 0.7965
# Epoch 00007: val_loss did not improve from 0.68002
# 126/126 [==============================] - 1s 6ms/step - loss: 0.6145 - accuracy: 0.7996 - val_loss: 0.7749 - val_accuracy: 0.7535
# Epoch 8/50
# 118/126 [===========================>..] - ETA: 0s - loss: 0.6126 - accuracy: 0.7971
# Epoch 00008: val_loss did not improve from 0.68002
# 126/126 [==============================] - 1s 5ms/step - loss: 0.6046 - accuracy: 0.8006 - val_loss: 0.7173 - val_accuracy: 0.7882
# Epoch 9/50
# 119/126 [===========================>..] - ETA: 0s - loss: 0.6033 - accuracy: 0.7983
# Epoch 00009: val_loss did not improve from 0.68002
# 126/126 [==============================] - 1s 6ms/step - loss: 0.5982 - accuracy: 0.8011 - val_loss: 0.6809 - val_accuracy: 0.7882
# Epoch 10/50
# 126/126 [==============================] - ETA: 0s - loss: 0.5834 - accuracy: 0.7986
# Epoch 00010: val_loss did not improve from 0.68002
# 126/126 [==============================] - 1s 5ms/step - loss: 0.5834 - accuracy: 0.7986 - val_loss: 0.7094 - val_accuracy: 0.7882
# Epoch 11/50
# 122/126 [============================>.] - ETA: 0s - loss: 0.5874 - accuracy: 0.7971
# Epoch 00011: val_loss improved from 0.68002 to 0.66918, saving model to .\checkpoint.h5
# 126/126 [==============================] - 1s 5ms/step - loss: 0.5856 - accuracy: 0.7981 - val_loss: 0.6692 - val_accuracy: 0.7917
# Epoch 12/50
# 126/126 [==============================] - ETA: 0s - loss: 0.5688 - accuracy: 0.7991
# Epoch 00012: val_loss did not improve from 0.66918
# 126/126 [==============================] - 1s 6ms/step - loss: 0.5688 - accuracy: 0.7991 - val_loss: 0.7105 - val_accuracy: 0.7917
# Epoch 13/50
# 120/126 [===========================>..] - ETA: 0s - loss: 0.5649 - accuracy: 0.8000
# Epoch 00013: val_loss did not improve from 0.66918
# 126/126 [==============================] - 1s 5ms/step - loss: 0.5638 - accuracy: 0.8006 - val_loss: 0.7170 - val_accuracy: 0.7917
# Epoch 14/50
# 122/126 [============================>.] - ETA: 0s - loss: 0.5614 - accuracy: 0.7976
# Epoch 00014: val_loss did not improve from 0.66918
# 126/126 [==============================] - 1s 5ms/step - loss: 0.5614 - accuracy: 0.7981 - val_loss: 0.7105 - val_accuracy: 0.7882
# Epoch 15/50
# 120/126 [===========================>..] - ETA: 0s - loss: 0.5641 - accuracy: 0.7995
# Epoch 00015: val_loss did not improve from 0.66918
# 126/126 [==============================] - 1s 5ms/step - loss: 0.5582 - accuracy: 0.8016 - val_loss: 0.6780 - val_accuracy: 0.7882
# Epoch 16/50
# 121/126 [===========================>..] - ETA: 0s - loss: 0.5456 - accuracy: 0.7986
# Epoch 00016: val_loss did not improve from 0.66918
# 126/126 [==============================] - 1s 5ms/step - loss: 0.5465 - accuracy: 0.7991 - val_loss: 0.7971 - val_accuracy: 0.7882
# Epoch 17/50
# 121/126 [===========================>..] - ETA: 0s - loss: 0.5411 - accuracy: 0.8011
# Epoch 00017: val_loss did not improve from 0.66918
# 126/126 [==============================] - 1s 5ms/step - loss: 0.5367 - accuracy: 0.8031 - val_loss: 0.7528 - val_accuracy: 0.7882
# Epoch 18/50
# 119/126 [===========================>..] - ETA: 0s - loss: 0.5459 - accuracy: 0.7915
# Epoch 00018: val_loss did not improve from 0.66918
# 126/126 [==============================] - 1s 6ms/step - loss: 0.5368 - accuracy: 0.7971 - val_loss: 0.7532 - val_accuracy: 0.7882
# Epoch 19/50
# 122/126 [============================>.] - ETA: 0s - loss: 0.5380 - accuracy: 0.8033
# Epoch 00019: val_loss did not improve from 0.66918
# 126/126 [==============================] - 1s 6ms/step - loss: 0.5368 - accuracy: 0.8031 - val_loss: 0.7222 - val_accuracy: 0.7882
# Epoch 20/50
# 121/126 [===========================>..] - ETA: 0s - loss: 0.5233 - accuracy: 0.8011
# Epoch 00020: val_loss did not improve from 0.66918
# 126/126 [==============================] - 1s 6ms/step - loss: 0.5283 - accuracy: 0.7986 - val_loss: 0.8081 - val_accuracy: 0.7882
# Epoch 21/50
# 126/126 [==============================] - ETA: 0s - loss: 0.5276 - accuracy: 0.8056
# Epoch 00021: val_loss did not improve from 0.66918
# 126/126 [==============================] - 1s 5ms/step - loss: 0.5276 - accuracy: 0.8056 - val_loss: 0.7841 - val_accuracy: 0.7882
# Epoch 22/50
# 122/126 [============================>.] - ETA: 0s - loss: 0.5280 - accuracy: 0.8064
# Epoch 00022: val_loss did not improve from 0.66918
# 126/126 [==============================] - 1s 6ms/step - loss: 0.5251 - accuracy: 0.8080 - val_loss: 0.8351 - val_accuracy: 0.7882
# Epoch 23/50
# 125/126 [============================>.] - ETA: 0s - loss: 0.5160 - accuracy: 0.8025
# Epoch 00023: val_loss did not improve from 0.66918
# 126/126 [==============================] - 1s 5ms/step - loss: 0.5151 - accuracy: 0.8026 - val_loss: 0.9203 - val_accuracy: 0.7917
# Epoch 24/50
# 125/126 [============================>.] - ETA: 0s - loss: 0.5273 - accuracy: 0.7995
# Epoch 00024: val_loss did not improve from 0.66918
# 126/126 [==============================] - 1s 5ms/step - loss: 0.5257 - accuracy: 0.8006 - val_loss: 0.8243 - val_accuracy: 0.7500
# Epoch 25/50
# 121/126 [===========================>..] - ETA: 0s - loss: 0.5141 - accuracy: 0.8042
# Epoch 00025: val_loss did not improve from 0.66918
# 126/126 [==============================] - 1s 5ms/step - loss: 0.5162 - accuracy: 0.8041 - val_loss: 0.8234 - val_accuracy: 0.7778
# Epoch 26/50
# 123/126 [============================>.] - ETA: 0s - loss: 0.5055 - accuracy: 0.8100
# Epoch 00026: val_loss did not improve from 0.66918
# 126/126 [==============================] - 1s 6ms/step - loss: 0.5116 - accuracy: 0.8061 - val_loss: 0.8412 - val_accuracy: 0.7882
# Epoch 27/50
# 116/126 [==========================>...] - ETA: 0s - loss: 0.5126 - accuracy: 0.8050
# Epoch 00027: val_loss did not improve from 0.66918
# 126/126 [==============================] - 1s 5ms/step - loss: 0.5128 - accuracy: 0.8046 - val_loss: 0.8807 - val_accuracy: 0.7882
# Epoch 28/50
# 117/126 [==========================>...] - ETA: 0s - loss: 0.5028 - accuracy: 0.8066
# Epoch 00028: val_loss did not improve from 0.66918
# 126/126 [==============================] - 1s 5ms/step - loss: 0.5049 - accuracy: 0.8070 - val_loss: 0.8797 - val_accuracy: 0.7639
# Epoch 29/50
# 119/126 [===========================>..] - ETA: 0s - loss: 0.5017 - accuracy: 0.8041
# Epoch 00029: val_loss did not improve from 0.66918
# 126/126 [==============================] - 1s 5ms/step - loss: 0.5054 - accuracy: 0.8036 - val_loss: 0.7996 - val_accuracy: 0.7917
# Epoch 30/50
# 117/126 [==========================>...] - ETA: 0s - loss: 0.4984 - accuracy: 0.8120
# Epoch 00030: val_loss did not improve from 0.66918
# 126/126 [==============================] - 1s 6ms/step - loss: 0.5032 - accuracy: 0.8100 - val_loss: 0.9697 - val_accuracy: 0.7778
# Epoch 31/50
# 121/126 [===========================>..] - ETA: 0s - loss: 0.4962 - accuracy: 0.8032
# Epoch 00031: val_loss did not improve from 0.66918
# 126/126 [==============================] - 1s 5ms/step - loss: 0.4908 - accuracy: 0.8075 - val_loss: 0.8836 - val_accuracy: 0.7882
# Epoch 32/50
# 118/126 [===========================>..] - ETA: 0s - loss: 0.4865 - accuracy: 0.8088
# Epoch 00032: val_loss did not improve from 0.66918
# 126/126 [==============================] - 1s 5ms/step - loss: 0.4887 - accuracy: 0.8080 - val_loss: 0.9141 - val_accuracy: 0.7847
# Epoch 33/50
# 124/126 [============================>.] - ETA: 0s - loss: 0.5068 - accuracy: 0.8065
# Epoch 00033: val_loss did not improve from 0.66918
# 126/126 [==============================] - 1s 6ms/step - loss: 0.5043 - accuracy: 0.8080 - val_loss: 0.8852 - val_accuracy: 0.7917
# Epoch 34/50
# 116/126 [==========================>...] - ETA: 0s - loss: 0.4981 - accuracy: 0.8050
# Epoch 00034: val_loss did not improve from 0.66918
# 126/126 [==============================] - 1s 5ms/step - loss: 0.4967 - accuracy: 0.8065 - val_loss: 0.9748 - val_accuracy: 0.7847
# Epoch 35/50
# 118/126 [===========================>..] - ETA: 0s - loss: 0.4959 - accuracy: 0.8114
# Epoch 00035: val_loss did not improve from 0.66918
# 126/126 [==============================] - 1s 6ms/step - loss: 0.4920 - accuracy: 0.8115 - val_loss: 0.8696 - val_accuracy: 0.7882
# Epoch 36/50
# 117/126 [==========================>...] - ETA: 0s - loss: 0.4859 - accuracy: 0.8088
# Epoch 00036: val_loss did not improve from 0.66918
# 126/126 [==============================] - 1s 5ms/step - loss: 0.4896 - accuracy: 0.8080 - val_loss: 0.9183 - val_accuracy: 0.7847
# Epoch 37/50
# 117/126 [==========================>...] - ETA: 0s - loss: 0.4796 - accuracy: 0.8088
# Epoch 00037: val_loss did not improve from 0.66918
# 126/126 [==============================] - 1s 5ms/step - loss: 0.4843 - accuracy: 0.8070 - val_loss: 0.8214 - val_accuracy: 0.7674
# Epoch 38/50
# 120/126 [===========================>..] - ETA: 0s - loss: 0.4823 - accuracy: 0.8120
# Epoch 00038: val_loss did not improve from 0.66918
# 126/126 [==============================] - 1s 5ms/step - loss: 0.4862 - accuracy: 0.8100 - val_loss: 0.8893 - val_accuracy: 0.7917
# Epoch 39/50
# 122/126 [============================>.] - ETA: 0s - loss: 0.4796 - accuracy: 0.8186
# Epoch 00039: val_loss did not improve from 0.66918
# 126/126 [==============================] - 1s 5ms/step - loss: 0.4810 - accuracy: 0.8180 - val_loss: 0.9428 - val_accuracy: 0.7882
# Epoch 40/50
# 119/126 [===========================>..] - ETA: 0s - loss: 0.4895 - accuracy: 0.8078
# Epoch 00040: val_loss did not improve from 0.66918
# 126/126 [==============================] - 1s 5ms/step - loss: 0.4898 - accuracy: 0.8080 - val_loss: 0.8576 - val_accuracy: 0.7882
# Epoch 41/50
# 119/126 [===========================>..] - ETA: 0s - loss: 0.4858 - accuracy: 0.8125
# Epoch 00041: val_loss did not improve from 0.66918
# 126/126 [==============================] - 1s 5ms/step - loss: 0.4873 - accuracy: 0.8120 - val_loss: 0.9411 - val_accuracy: 0.7778
# Epoch 42/50
# 118/126 [===========================>..] - ETA: 0s - loss: 0.4786 - accuracy: 0.8141
# Epoch 00042: val_loss did not improve from 0.66918
# 126/126 [==============================] - 1s 5ms/step - loss: 0.4763 - accuracy: 0.8145 - val_loss: 0.9811 - val_accuracy: 0.7708
# Epoch 43/50
# 120/126 [===========================>..] - ETA: 0s - loss: 0.4831 - accuracy: 0.8120
# Epoch 00043: val_loss did not improve from 0.66918
# 126/126 [==============================] - 1s 5ms/step - loss: 0.4802 - accuracy: 0.8140 - val_loss: 0.8737 - val_accuracy: 0.7882
# Epoch 44/50
# 118/126 [===========================>..] - ETA: 0s - loss: 0.4813 - accuracy: 0.8104
# Epoch 00044: val_loss did not improve from 0.66918
# 126/126 [==============================] - 1s 5ms/step - loss: 0.4842 - accuracy: 0.8090 - val_loss: 0.9282 - val_accuracy: 0.7917
# Epoch 45/50
# 119/126 [===========================>..] - ETA: 0s - loss: 0.4632 - accuracy: 0.8162
# Epoch 00045: val_loss did not improve from 0.66918
# 126/126 [==============================] - 1s 5ms/step - loss: 0.4670 - accuracy: 0.8120 - val_loss: 0.9464 - val_accuracy: 0.7743
# Epoch 46/50
# 121/126 [===========================>..] - ETA: 0s - loss: 0.4730 - accuracy: 0.8094
# Epoch 00046: val_loss did not improve from 0.66918
# 126/126 [==============================] - 1s 5ms/step - loss: 0.4708 - accuracy: 0.8105 - val_loss: 0.8771 - val_accuracy: 0.7882
# Epoch 47/50
# 120/126 [===========================>..] - ETA: 0s - loss: 0.4788 - accuracy: 0.8068
# Epoch 00047: val_loss did not improve from 0.66918
# 126/126 [==============================] - 1s 5ms/step - loss: 0.4783 - accuracy: 0.8075 - val_loss: 0.9544 - val_accuracy: 0.7708
# Epoch 48/50
# 121/126 [===========================>..] - ETA: 0s - loss: 0.4650 - accuracy: 0.8156
# Epoch 00048: val_loss did not improve from 0.66918
# 126/126 [==============================] - 1s 5ms/step - loss: 0.4635 - accuracy: 0.8165 - val_loss: 0.9425 - val_accuracy: 0.7812
# Epoch 49/50
# 116/126 [==========================>...] - ETA: 0s - loss: 0.4623 - accuracy: 0.8179
# Epoch 00049: val_loss did not improve from 0.66918
# 126/126 [==============================] - 1s 5ms/step - loss: 0.4631 - accuracy: 0.8170 - val_loss: 0.9448 - val_accuracy: 0.7812
# Epoch 50/50
# 121/126 [===========================>..] - ETA: 0s - loss: 0.4712 - accuracy: 0.8213
# Epoch 00050: val_loss did not improve from 0.66918
# 126/126 [==============================] - 1s 5ms/step - loss: 0.4660 - accuracy: 0.8229 - val_loss: 0.9167 - val_accuracy: 0.7882

# %%
# load optimal weights
model.load_weights('./checkpoint.h5')

# %%
###############################################################################
# make prediction on test set.
###############################################################################

probs       = model.predict(X_test)
print(probs)
preds       = probs.argmax(axis = -1)
acc         = np.mean(preds == Y_test.argmax(axis=-1))
print("Classification accuracy: %.4f " % (acc))
# Out:
# [[0.8815735  0.05577943 0.06264712]
#  [0.7400124  0.12334888 0.13663873]
#  [0.73873776 0.11558453 0.14567773]
#  ...
#  [0.56573653 0.20434725 0.2299162 ]
#  [0.90165544 0.05310582 0.0452388 ]
#  [0.37122622 0.27427816 0.35449558]]
# Classification accuracy: 0.7817

# %%
import matplotlib.pyplot as plt
fig, ax = plt.subplots(2)
ax[0].plot(losses)
ax[0].set_ylabel('Loss')
ax[0].set_xlabel('Epochs')
ax[1].plot(accs)
ax[1].set_ylabel('Accuracy')
ax[1].set_xlabel('Epochs')
plt.show()
